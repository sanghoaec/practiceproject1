# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import numpy as np
from matplotlib.ticker import MaxNLocator

# %%
clean_data = pd.read_csv('E:\happiness_score_dataset.csv')

# %%
clean_data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
cleaned_region = clean_data.ffill(axis = 0)
cleaned_region
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
grouped_country_df = cleaned_region.groupby(['Region'])

# %%
sum_hapiness = grouped_country_df['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity'].mean()
sum_hapiness
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10864/3480588165.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_hapiness = grouped_country_df['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity'].mean()
#                                  Economy (GDP per Capita)    Family  \
# Region
# Australia and New Zealand                        1.291880  1.314450
# Central and Eastern Europe                       0.942438  1.053042
# Eastern Asia                                     1.151780  1.099427
# Latin America and Caribbean                      0.876815  1.104720
# Middle East and Northern Africa                  1.066974  0.920490
# North America                                    1.360400  1.284860
# Southeastern Asia                                0.789054  0.940468
# Southern Asia                                    0.560486  0.645321
# ...

# %%
multi_plot = sum_hapiness.plot(kind='barh', figsize=(10,10), title = "Factors by Region")
plt.legend(bbox_to_anchor=(1,0.9), loc="upper right")
